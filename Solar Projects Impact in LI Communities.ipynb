# %% [markdown]
# ### Solar Potential of Low Income Communities in the United States
#
# This code cleans and combines various datasets from:
# - Google Sunroof
# - Energy Equity Project
# - Justice 40

# %%
import pandas as pd

# %%
## load Project Sunroof Data
sr_data = pd.read_csv("data/project-sunroof-census_tract.csv")
print(sr_data.head(5))

## Update column name and change format to match GEOID in other datasets
# sr_data = sr_data.rename(columns={"region_name": "GEOID"})
# sr_data["GEOID"] = sr_data["GEOID"].apply(lambda x: "0" + str(x))
# sr_data["GEOID"].head(5)
#sr_data.to_csv("Data/sunroof_data.csv")
# Out:
#    region_name state_name    lat_max    lat_min    lng_max    lng_min
# 0   1001020100    Alabama  32.505161  32.449730 -86.475128 -86.510422  \
# 1   1001020200    Alabama  32.489342  32.456120 -86.465378 -86.481270
# 2   1001020300    Alabama  32.491909  32.459209 -86.450684 -86.470871
# 3   1001020400    Alabama  32.493690  32.447208 -86.432381 -86.453941
# 4   1001020500    Alabama  32.485748  32.424000 -86.411346 -86.438423
#
#      lat_avg    lng_avg  yearly_sunlight_kwh_kw_threshold_avg
# 0  32.477184 -86.490082                               1095.65  \
# 1  32.474255 -86.473381                               1095.65
# 2  32.475426 -86.460190                               1095.65
# 3  32.472000 -86.443619                               1095.65
# 4  32.458832 -86.422661                               1095.65
#
#    count_qualified  ...  yearly_sunlight_kwh_n  yearly_sunlight_kwh_s
# 0              591  ...           6.735739e+05           3.744787e+06  \
# ...

# %%
#load Energy Equity Project Data
eep_data = pd.read_csv("data/eep_final_data.csv")
print(eep_data.head(5))
# Out:
#    STATEFP  COUNTYFP  TRACTCE              AFFGEOID        GEOID     NAME
# 0       13       163   960300  1400000US13163960300  13163960300  9603.00  \
# 1       37       109    71201  1400000US37109071201  37109071201   712.01
# 2       25        25    50200  1400000US25025050200  25025050200   502.00
# 3       17        31   230200  1400000US17031230200  17031230200  2302.00
# 4       41        47     1607  1400000US41047001607  41047001607    16.07
#
#               NAMELSAD STUSPS        NAMELSADCO      STATE_NAME  ...
# 0    Census Tract 9603     GA  Jefferson County         Georgia  ...  \
# 1  Census Tract 712.01     NC    Lincoln County  North Carolina  ...
# 2     Census Tract 502     MA    Suffolk County   Massachusetts  ...
# 3    Census Tract 2302     IL       Cook County        Illinois  ...
# 4   Census Tract 16.07     OR     Marion County          Oregon  ...
#
#   seniors_living_alone  median_income  owner_occupied  renter_occupied
# ...

# %%
#load Justice40 Data
j40_data = pd.read_csv("data/1.0-communities.csv")
print(j40_data.head(5))
# Out:
#    Census tract 2010 ID     County Name State/Territory
# 0            1001020100  Autauga County         Alabama  \
# 1            1001020200  Autauga County         Alabama
# 2            1001020300  Autauga County         Alabama
# 3            1001020400  Autauga County         Alabama
# 4            1001020500  Autauga County         Alabama
#
#    Percent Black or African American alone
# 0                                     0.07  \
# 1                                     0.57
# 2                                     0.24
# 3                                     0.05
# 4                                     0.18
#
#    Percent American Indian / Alaska Native  Percent Asian
# 0                                      0.0           0.00  \
# 1                                      0.0           0.00
# 2                                      0.0           0.00
# 3                                      0.0           0.00
# 4                                      0.0           0.03
#
# ...
